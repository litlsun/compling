# %% [markdown]
# <a href="https://colab.research.google.com/github/litlsun/compling/blob/main/Twilight_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/litlsun/crispy-spoon/refs/heads/main/Twilight
# Out:
# --2024-11-24 14:09:34--  https://raw.githubusercontent.com/litlsun/crispy-spoon/refs/heads/main/Twilight
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 654901 (640K) [text/plain]
# Saving to: ‘Twilight’
#
# Twilight            100%[===================>] 639.55K  --.-KB/s    in 0.07s
#
# 2024-11-24 14:09:34 (8.44 MB/s) - ‘Twilight’ saved [654901/654901]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import defaultdict
import re

# %%
file_path = '/content/Twilight'

# %%
with open(file_path, 'r', encoding='utf-8') as file:
  text = file.read()

# %%
text = text.lower()
text[500:1000]
# Out:
# "reathing across the long room, into the dark eyes of the hunter, and he looked pleasantly back at me.\nsurely it was a good way to die, in the place of someone else, someone i loved. noble, even. that ought to count for something.\ni knew that if i'd never gone to forks, i wouldn't be facing death now. but, terrified as i was, i couldn't bring myself to regret the decision. when life offers you a dream so far beyond any of your expectations, it's not reasonable to grieve when it comes to an end.\nt"

# %%
text = re.sub(r'[^a-z\s\.\?!]', '', text)
text[500:1000]
# Out:
# 'ss the long room into the dark eyes of the hunter and he looked pleasantly back at me.\nsurely it was a good way to die in the place of someone else someone i loved. noble even. that ought to count for something.\ni knew that if id never gone to forks i wouldnt be facing death now. but terrified as i was i couldnt bring myself to regret the decision. when life offers you a dream so far beyond any of your expectations its not reasonable to grieve when it comes to an end.\nthe hunter smiled in a frie'

# %%
sentences = re.split(r'[\.\?!]', text)
sentences[1:3]
# Out:
# ['  \n\nbut of the tree of the knowledge of good and evil  \nthou shalt not eat of it  \nfor in the day that thou eatest thereof  \nthou shalt surely die',
#  '  \ngenesis  \n\npreface\n\nid never given much thought to how i would die  though id had reason enough in the last few months  but even if i had i would not have imagined it like this']

# %%
sentences = [sentence.split() for sentence in sentences if sentence]
sentences[3]
# Out:
# ['i',
#  'stared',
#  'without',
#  'breathing',
#  'across',
#  'the',
#  'long',
#  'room',
#  'into',
#  'the',
#  'dark',
#  'eyes',
#  'of',
#  'the',
#  'hunter',
#  'and',
#  'he',
#  'looked',
#  'pleasantly',
#  'back',
#  'at',
#  'me']

# %%
co_occurrence = defaultdict(lambda: defaultdict(int))

# %%
def update_co_occurrence(sentence, window_size=1):
    words = ["<START>"] + sentence + ["<END>"]
    for i, word in enumerate(words):
        for j in range(max(0, i - window_size), min(len(words), i + window_size + 1)):
            if i != j:
                co_occurrence[word][words[j]] += 1

for sentence in sentences:
    update_co_occurrence(sentence)

co_occurrence['vampire']
# Out:
# defaultdict(int,
#             {'the': 8,
#              'fangs': 2,
#              '<START>': 2,
#              '<END>': 10,
#              'who': 6,
#              'filipino': 2,
#              'supposedly': 2,
#              'most': 2,
#              'myths': 2,
#              'italian': 2,
#              'said': 2,
#              'a': 10,
#              'i': 6,
#              'unreliable': 2,
#              'your': 2,
#              'sweetheart': 2,
#              'his': 2,
#              'family': 2,
#              'old': 2,
#              'made': 2,
#              'new': 2,
#              'and': 2,
#              'attack': 2,
#              'sadistic': 2,
#              'intent': 2,
#              'real': 2,
#              'of': 2,
#              'conversions': 2,
#              'only': 2})

# %%
tokens = list(co_occurrence.keys())
tokens[:10]
# Out:
# ['<START>',
#  'stephenie',
#  'meyer',
#  'twilight',
#  'for',
#  'my',
#  'big',
#  'sister',
#  'emily',
#  'without']

# %%
co_occurrence_df = pd.DataFrame(co_occurrence).fillna(0).astype(int).reindex(tokens, columns=tokens, fill_value=0)
co_occurrence_df
# Out:
#               <START>  stephenie  meyer  twilight  for   my  big  sister  \
# <START>             0          2      0         2   46  378    2       0
# stephenie           2          0      4         2    0    0    0       0
# meyer               0          4      0         4    0    0    0       0
# twilight            2          2      4         0    2    0    0       0
# for                46          0      0         2    0   54    0       0
# ...               ...        ...    ...       ...  ...  ...  ...     ...
# particularly        0          0      0         0    0    0    0       0
# kimberly            0          0      0         0    0    0    0       0
# shazzer             0          0      0         0    0    0    0       0
# collin              0          0      0         0    0    0    0       0
# mantenna            0          0      0         0    2    0    0       0
#
#               emily  without  ...  online  talented  staff  fansofrealitytv  \
# <START>           0        8  ...       0         0      0                0
# stephenie         0        0  ...       0         0      0                0
# meyer             0        0  ...       0         0      0                0
# twilight          0        0  ...       0         0      0                0
# for               0        0  ...       0         0      0                0
# ...             ...      ...  ...     ...       ...    ...              ...
# particularly      0        0  ...       0         0      0                0
# kimberly          0        0  ...       0         0      0                0
# shazzer           0        0  ...       0         0      0                0
# collin            0        0  ...       0         0      0                0
# mantenna          0        0  ...       0         0      0                0
#
#               com  particularly  kimberly  shazzer  collin  mantenna
# <START>         2             0         0        0       0         0
# stephenie       0             0         0        0       0         0
# meyer           0             0         0        0       0         0
# twilight        0             0         0        0       0         0
# for             0             0         0        0       0         2
# ...           ...           ...       ...      ...     ...       ...
# particularly    2             0         2        0       0         0
# kimberly        0             2         0        2       0         0
# shazzer         0             0         2        0       0         0
# collin          0             0         0        0       0         2
# mantenna        0             0         0        0       2         0
#
# [8166 rows x 8166 columns]
