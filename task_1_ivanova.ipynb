# %% [markdown]
# <a href="https://colab.research.google.com/github/litlsun/compling/blob/main/task_1_ivanova.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Задача 1: разработка пайплайна предобработки текста с ООП
# Цель:
# Hазработать класс на Python с использованием принципов объектно-ориентированного программирования (ООП), который реализует пайплайн для предобработки текста
#
# Методы, которые должен реализовывать разработанный класс:
#
# 1.   Токенизация
# 2.   Лемматизация
# 3.   Удаление стоп-слов

# %% [markdown]
# **Шаг 1. Устанавливаем необходимые библиотеки**

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
# Убедитесь, что необходимые ресурсы NLTK загружены
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# **Шаг 2. Подгружаем текст, который необходимо обработать**
#
#
# Открываем его в кодировке utf-8

# %%
# !wget -O orwell.txt https://gist.githubusercontent.com/vlandham/2549b64121112dd9e4dacc47c959472a/raw/4e6883bbab5ab0d42fc4b9555d93e22aefd7baed/1984.txt
with open("orwell.txt", "r", encoding="utf-8") as file:
    text = file.read()
# Out:
# --2025-01-29 11:34:20--  https://gist.githubusercontent.com/vlandham/2549b64121112dd9e4dacc47c959472a/raw/4e6883bbab5ab0d42fc4b9555d93e22aefd7baed/1984.txt
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35439 (35K) [text/plain]
# Saving to: ‘orwell.txt’
#
# orwell.txt          100%[===================>]  34.61K  --.-KB/s    in 0.008s
#
# 2025-01-29 11:34:20 (4.11 MB/s) - ‘orwell.txt’ saved [35439/35439]

# %% [markdown]
# **Создание класса**
#
# Определим класс TextProcessor, который будет содержать методы для предобработки текста.

# %%
class TextProcessor:
    def __init__(self, text):
        """
        Инициализация класса с исходным текстом.
        """
        self.text = text
        self.tokens = []
        self.cleaned_tokens = []
        self.lemmatizer = WordNetLemmatizer()
        self.stop_words = set(stopwords.words('english'))

# %% [markdown]
# **Метод токенизации**
#
# Реализация метода, который разделяет текст на отдельные слова.

# %%
    def tokenize(self):
        """
        Метод для токенизации текста.
        """
        self.tokens = word_tokenize(self.text)
        return self.tokens

# %% [markdown]
# **Метод лемматизации**
#
# Добавляем метод, который преобразует слова к их леммам. Для этого обращаемся к `WordNetLemmatizer` из NLTK.

# %%
    def lemmatize(self):
        """
        Лемматизация.
        Преобразует каждое слово в его базовую форму.
        """
        self.tokens = [self.lemmatizer.lemmatize(word.lower()) for word in self.tokens]
        return self.tokens

# %% [markdown]
# **Метод удаления стоп-слов**
#
# Добавляем метод для удаления стоп-слов из токенов с помощью списка стоп-слов из NLTK.

# %%
    def remove_stopwords(self):
        """
        Удаление стоп-слов.
        Удаляет из текста все стоп-слова.
        """
        self.cleaned_tokens = [token for token in self.tokens if token not in self.stop_words]
        return self.cleaned_tokens

# %% [markdown]
# **Запуск пайплайна**

# %%
class TextProcessor:
    def __init__(self, text):
        """
        Инициализация класса с исходным текстом.
        """
        self.text = text
        self.tokens = []
        self.cleaned_tokens = []
        self.lemmatizer = WordNetLemmatizer()
        self.stop_words = set(stopwords.words('english'))
    def tokenize(self):
        """
        Метод для токенизации текста.
        """
        self.tokens = word_tokenize(self.text)
        return self.tokens
    def lemmatize(self):
        """
        Лемматизация.
        Преобразует каждое слово в его базовую форму.
        """
        self.tokens = [self.lemmatizer.lemmatize(word.lower()) for word in self.tokens]
        return self.tokens
    def remove_stopwords(self):
        """
        Удаление стоп-слов.
        Удаляет из текста все стоп-слова.
        """
        self.cleaned_tokens = [token for token in self.tokens if token not in self.stop_words]
        return self.cleaned_tokens

processor = TextProcessor(text)
processor.tokenize()
processor.remove_stopwords()
processor.lemmatize()


# Вывод итогового результата
print("Токены:", processor.tokens)
print("Лемматизированные токены:", processor.cleaned_tokens)
# Out:
# Токены: ['it', 'wa', 'a', 'bright', 'cold', 'day', 'in', 'april', ',', 'and', 'the', 'clock', 'were', 'striking', 'thirteen', '.', 'winston', 'smith', ',', 'his', 'chin', 'nuzzled', 'into', 'his', 'breast', 'in', 'an', 'effort', 'to', 'escape', 'the', 'vile', 'wind', ',', 'slipped', 'quickly', 'through', 'the', 'glass', 'door', 'of', 'victory', 'mansion', ',', 'though', 'not', 'quickly', 'enough', 'to', 'prevent', 'a', 'swirl', 'of', 'gritty', 'dust', 'from', 'entering', 'along', 'with', 'him', '.', 'the', 'hallway', 'smelt', 'of', 'boiled', 'cabbage', 'and', 'old', 'rag', 'mat', '.', 'at', 'one', 'end', 'of', 'it', 'a', 'coloured', 'poster', ',', 'too', 'large', 'for', 'indoor', 'display', ',', 'had', 'been', 'tacked', 'to', 'the', 'wall', '.', 'it', 'depicted', 'simply', 'an', 'enormous', 'face', ',', 'more', 'than', 'a', 'metre', 'wide', ':', 'the', 'face', 'of', 'a', 'man', 'of', 'about', 'forty-five', ',', 'with', 'a', 'heavy', 'black', 'moustache', 'and', 'ruggedly', 'handsome', 'feature', '.', 'winston', 'made', 'for', 'the', 'stair', '.', 'it', 'wa', 'no', 'use', 'trying', 'the', 'lift', '.', 'even', 'at', 'the', 'best', 'of', 'time', 'it', 'wa', 'seldom', 'working', ',', 'and', 'at', 'present', 'the', 'electric', 'current', 'wa', 'cut', 'off', 'during', 'daylight', 'hour', '.', 'it', 'wa', 'part', 'of', 'the', 'economy', 'drive', 'in', 'preparation', 'for', 'hate', 'week', '.', 'the', 'flat', 'wa', 'seven', 'flight', 'up', ',', 'and', 'winston', ',', 'who', 'wa', 'thirty-nine', 'and', 'had', 'a', 'varicose', 'ulcer', 'above', 'his', 'right', 'ankle', ',', 'went', 'slowly', ',', 'resting', 'several', 'time', 'on', 'the', 'way', '.', 'on', 'each', 'landing', ',', 'opposite', 'the', 'lift-shaft', ',', 'the', 'poster', 'with', 'the', 'enormous', 'face', 'gazed', 'from', 'the', 'wall', '.', 'it', 'wa', 'one', 'of', 'those', 'picture', 'which', 'are', 'so', 'contrived', 'that', 'the', 'eye', 'follow', 'you', 'about', 'when', 'you', 'move', '.', 'big', 'brother', 'is', 'watching', 'you', ',', 'the', 'caption', 'beneath', 'it', 'ran', '.', 'inside', 'the', 'flat', 'a', 'fruity', 'voice', 'wa', 'reading', 'out', 'a', 'list', 'of', 'figure', 'which', 'had', 'something', 'to', 'do', 'with', 'the', 'production', 'of', 'pig-iron', '.', 'the', 'voice', 'came', 'from', 'an', 'oblong', 'metal', 'plaque', 'like', 'a', 'dulled', 'mirror', 'which', 'formed', 'part', 'of', 'the', 'surface', 'of', 'the', 'right-hand', 'wall', '.', 'winston', 'turned', 'a', 'switch', 'and', 'the', 'voice', 'sank', 'somewhat', ',', 'though', 'the', 'word', 'were', 'still', 'distinguishable', '.', 'the', 'instrument', '(', 'the', 'telescreen', ',', 'it', 'wa', 'called', ')', 'could', 'be', 'dimmed', ',', 'but', 'there', 'wa', 'no', 'way', 'of', 'shutting', 'it', 'off', 'completely', '.', 'he', 'moved', 'over', 'to', 'the', 'window', ':', 'a', 'smallish', ',', 'frail', 'figure', ',', 'the', 'meagreness', 'of', 'his', 'body', 'merely', 'emphasized', 'by', 'the', 'blue', 'overall', 'which', 'were', 'the', 'uniform', 'of', 'the', 'party', '.', 'his', 'hair', 'wa', 'very', 'fair', ',', 'his', 'face', 'naturally', 'sanguine', ',', 'his', 'skin', 'roughened', 'by', 'coarse', 'soap', 'and', 'blunt', 'razor', 'blade', 'and', 'the', 'cold', 'of', 'the', 'winter', 'that', 'had', 'just', 'ended', '.', 'outside', ',', 'even', 'through', 'the', 'shut', 'window-pane', ',', 'the', 'world', 'looked', 'cold', '.', 'down', 'in', 'the', 'street', 'little', 'eddy', 'of', 'wind', 'were', 'whirling', 'dust', 'and', 'torn', 'paper', 'into', 'spiral', ',', 'and', 'though', 'the', 'sun', 'wa', 'shining', 'and', 'the', 'sky', 'a', 'harsh', 'blue', ',', 'there', 'seemed', 'to', 'be', 'no', 'colour', 'in', 'anything', ',', 'except', 'the', 'poster', 'that', 'were', 'plastered', 'everywhere', '.', 'the', 'blackmoustachio', "'d", 'face', 'gazed', 'down', 'from', 'every', 'commanding', 'corner', '.', 'there', 'wa', 'one', 'on', 'the', 'house-front', 'immediately', 'opposite', '.', 'big', ' ...
# Лемматизированные токены: ['It', 'bright', 'cold', 'day', 'April', ',', 'clocks', 'striking', 'thirteen', '.', 'Winston', 'Smith', ',', 'chin', 'nuzzled', 'breast', 'effort', 'escape', 'vile', 'wind', ',', 'slipped', 'quickly', 'glass', 'doors', 'Victory', 'Mansions', ',', 'though', 'quickly', 'enough', 'prevent', 'swirl', 'gritty', 'dust', 'entering', 'along', '.', 'The', 'hallway', 'smelt', 'boiled', 'cabbage', 'old', 'rag', 'mats', '.', 'At', 'one', 'end', 'coloured', 'poster', ',', 'large', 'indoor', 'display', ',', 'tacked', 'wall', '.', 'It', 'depicted', 'simply', 'enormous', 'face', ',', 'metre', 'wide', ':', 'face', 'man', 'forty-five', ',', 'heavy', 'black', 'moustache', 'ruggedly', 'handsome', 'features', '.', 'Winston', 'made', 'stairs', '.', 'It', 'use', 'trying', 'lift', '.', 'Even', 'best', 'times', 'seldom', 'working', ',', 'present', 'electric', 'current', 'cut', 'daylight', 'hours', '.', 'It', 'part', 'economy', 'drive', 'preparation', 'Hate', 'Week', '.', 'The', 'flat', 'seven', 'flights', ',', 'Winston', ',', 'thirty-nine', 'varicose', 'ulcer', 'right', 'ankle', ',', 'went', 'slowly', ',', 'resting', 'several', 'times', 'way', '.', 'On', 'landing', ',', 'opposite', 'lift-shaft', ',', 'poster', 'enormous', 'face', 'gazed', 'wall', '.', 'It', 'one', 'pictures', 'contrived', 'eyes', 'follow', 'move', '.', 'BIG', 'BROTHER', 'IS', 'WATCHING', 'YOU', ',', 'caption', 'beneath', 'ran', '.', 'Inside', 'flat', 'fruity', 'voice', 'reading', 'list', 'figures', 'something', 'production', 'pig-iron', '.', 'The', 'voice', 'came', 'oblong', 'metal', 'plaque', 'like', 'dulled', 'mirror', 'formed', 'part', 'surface', 'right-hand', 'wall', '.', 'Winston', 'turned', 'switch', 'voice', 'sank', 'somewhat', ',', 'though', 'words', 'still', 'distinguishable', '.', 'The', 'instrument', '(', 'telescreen', ',', 'called', ')', 'could', 'dimmed', ',', 'way', 'shutting', 'completely', '.', 'He', 'moved', 'window', ':', 'smallish', ',', 'frail', 'figure', ',', 'meagreness', 'body', 'merely', 'emphasized', 'blue', 'overalls', 'uniform', 'party', '.', 'His', 'hair', 'fair', ',', 'face', 'naturally', 'sanguine', ',', 'skin', 'roughened', 'coarse', 'soap', 'blunt', 'razor', 'blades', 'cold', 'winter', 'ended', '.', 'Outside', ',', 'even', 'shut', 'window-pane', ',', 'world', 'looked', 'cold', '.', 'Down', 'street', 'little', 'eddies', 'wind', 'whirling', 'dust', 'torn', 'paper', 'spirals', ',', 'though', 'sun', 'shining', 'sky', 'harsh', 'blue', ',', 'seemed', 'colour', 'anything', ',', 'except', 'posters', 'plastered', 'everywhere', '.', 'The', 'blackmoustachio', "'d", 'face', 'gazed', 'every', 'commanding', 'corner', '.', 'There', 'one', 'house-front', 'immediately', 'opposite', '.', 'BIG', 'BROTHER', 'IS', 'WATCHING', 'YOU', ',', 'caption', 'said', ',', 'dark', 'eyes', 'looked', 'deep', 'Winston', "'s", '.', 'Down', 'streetlevel', 'another', 'poster', ',', 'torn', 'one', 'corner', ',', 'flapped', 'fitfully', 'wind', ',', 'alternately', 'covering', 'uncovering', 'single', 'word', 'INGSOC', '.', 'In', 'far', 'distance', 'helicopter', 'skimmed', 'roofs', ',', 'hovered', 'instant', 'like', 'bluebottle', ',', 'darted', 'away', 'curving', 'flight', '.', 'It', 'police', 'patrol', ',', 'snooping', 'people', "'s", 'windows', '.', 'The', 'patrols', 'matter', ',', 'however', '.', 'Only', 'Thought', 'Police', 'mattered', '.', 'Behind', 'Winston', "'s", 'back', 'voice', 'telescreen', 'still', 'babbling', 'away', 'pig-iron', 'overfulfilment', 'Ninth', 'Three-Year', 'Plan', '.', 'The', 'telescreen', 'received', 'transmitted', 'simultaneously', '.', 'Any', 'sound', 'Winston', 'made', ',', 'level', 'low', 'whisper', ',', 'would', 'picked', ',', 'moreover', ',', 'long', 'remained', 'within', 'field', 'vision', 'metal', 'plaque', 'commanded', ',', 'could', 'seen', 'well', 'heard', '.', 'There', 'course', 'way', 'knowing', 'whether', 'watched', 'given', 'moment', '.', 'How', 'often', ',', 'system', ',', 'Thought', 'Police', 'plugged', 'individual', 'wire', 'g ...
